# %%
import pandas as pd
import os
from datetime import datetime as dt

# %%
#pandas options
import pandas as pd
pd.set_option('display.max_rows', None)

# %%
#!py -m pip install openpyxl --upgrade

# %%
#change to payroll teams documents folder, note that this needs to be synched to your directory for this to work
os.chdir(r"C:\Users\alex.jefferies\Leighs Construction Limited\People and Culture - 11 Payroll - People Dashboard Data Sources")

# %%
#helper functions
# Assuming 'df' is your DataFrame
def missing_info(df:pd.DataFrame):
    total_rows = len(df)
    missing_values_count = df.isnull().sum()
    missing_values_ratio = (missing_values_count / total_rows)

    missing_values_df = pd.DataFrame({'missing_count': missing_values_count, 'missing_ratio': missing_values_ratio})
    print(missing_values_df)

def time_convert(atime):
    newtime = dt.fromtimestamp(atime)
    return newtime.date()

def create_file_records(somepath) -> dict:
    #dictionary
    firstDict = {}
    
    for name in os.listdir(somepath): 

        if ".xlsx" in name or ".csv" in name.lower():
    
            filepath = os.path.join(somepath, name)
            
            #main library that holds stats
            stats = os.stat(filepath)
            
            attrs = {
                'File Name': name,
                #'Size (KB)': sizeFormat(stats.st_size),
                'Creation Date': time_convert(stats.st_ctime),
                'Modified Date': time_convert(stats.st_mtime),
                'Last Access Date': time_convert(stats.st_atime),
                
            }
           
            firstDict[name] = attrs 

    return firstDict 

def view_records(file_records) -> None:
    
    for key, value in file_records.items():
            
        for k,v in value.items():
            print(f"{k}: {v}")
        print()

def get_info(df:pd.DataFrame):
    print("="*50)
    print(df.shape)
    print(df.head())
    print()
    print(df.info())
    print()
    print("="*50)

# %%
current_path = os.getcwd()
subdirs = [os.path.join(current_path, d) for d in os.listdir(current_path) if os.path.isdir(os.path.join(current_path, d))]

# Sort the subdirectories by their creation time in descending order
sorted_subdirs = sorted(subdirs, key=os.path.getctime, reverse=True)

# Get the latest subdirectory
latest_subdir = sorted_subdirs[0]
os.chdir(latest_subdir)

# %%
latest_subdir
# Out:
# 'C:\\Users\\alex.jefferies\\Leighs Construction Limited\\People and Culture - 11 Payroll - People Dashboard Data Sources\\240601'

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 9841-01DE
#
#  Directory of C:\Users\alex.jefferies\Leighs Construction Limited\People and Culture - 11 Payroll - People Dashboard Data Sources\240601
#
# 05/30/2024  08:28 AM    <DIR>          .
# 06/04/2024  08:39 AM    <DIR>          ..
# 05/30/2024  07:59 AM          (21,028) 240601 NorthSalaries EmployeeList.xlsx
# 05/30/2024  08:00 AM           (2,250) 240601 NORTHSALARIES LEAVEBALANCES.CSV
# 05/30/2024  08:00 AM          (31,911) 240601 NorthSalaries TerminatedEmployees.xlsx
# 05/30/2024  08:05 AM          (20,634) 240601 NorthWages EmployeeList.xlsx
# 05/30/2024  08:07 AM           (2,481) 240601 NORTHWAGES LEAVEBALANCES.CSV
# 05/30/2024  08:06 AM          (23,689) 240601 NorthWages TerminatedEmployees.xlsx
# 05/30/2024  08:01 AM          (23,408) 240601 SouthSalaries EmployeeList.xlsx
# 05/30/2024  08:02 AM          (32,979) 240601 SouthSalaries TerminatedEmployees.xlsx
# 05/30/2024  08:03 AM          (21,199) 240601 SouthWages EmployeeList.xlsx
# 05/30/2024  08:03 AM           (2,701) 240601 SOUTHWAGES LEAVEBALANCES.CSV
# 05/30/2024  08:04 AM          (51,394) 240601 SouthWages TerminatedEmployees.xlsx
# 05/30/2024  08:02 AM           (3,285) 240601SOUTHSALARIES LEAVEBALANCES.CSV
#               12 File(s)        236,959 bytes
#                2 Dir(s)  875,749,339,136 bytes free

# %% [markdown]
# ### Directory sorting and filtering

# %%
file_records = create_file_records(latest_subdir)

# %%
view_records(file_records)
# Out:
# File Name: 240601 NorthSalaries EmployeeList.xlsx
# Creation Date: 2024-05-30
# Modified Date: 2024-05-30
# Last Access Date: 2024-05-30
#
# File Name: 240601 NORTHSALARIES LEAVEBALANCES.CSV
# Creation Date: 2024-05-30
# Modified Date: 2024-05-30
# Last Access Date: 2024-05-30
#
# File Name: 240601 NorthSalaries TerminatedEmployees.xlsx
# Creation Date: 2024-05-30
# Modified Date: 2024-05-30
# Last Access Date: 2024-05-30
#
# File Name: 240601 NorthWages EmployeeList.xlsx
# Creation Date: 2024-05-30
# Modified Date: 2024-05-30
# Last Access Date: 2024-05-30
#
# File Name: 240601 NORTHWAGES LEAVEBALANCES.CSV
# Creation Date: 2024-05-30
# Modified Date: 2024-05-30
# Last Access Date: 2024-05-30
#
# File Name: 240601 NorthWages TerminatedEmployees.xlsx
# Creation Date: 2024-05-30
# Modified Date: 2024-05-30
# Last Access Date: 2024-05-30
#
# File Name: 240601 SouthSalaries EmployeeList.xlsx
# Creation Date: 2024-05-30
# Modified Date: 2024-05-30
# Last Access Date: 2024-05-30
#
# File Name: 240601 SouthSalaries TerminatedEmployees.xlsx
# Creation Date: 2024-05-30
# Modified Date: 2024-05-30
# Last Access Date: 2024-05-30
#
# File Name: 240601 SouthWages EmployeeList.xlsx
# Creation Date: 2024-05-30
# Modified Date: 2024-05-30
# Last Access Date: 2024-05-30
#
# File Name: 240601 SOUTHWAGES LEAVEBALANCES.CSV
# Creation Date: 2024-05-30
# Modified Date: 2024-05-30
# Last Access Date: 2024-05-30
#
# File Name: 240601 SouthWages TerminatedEmployees.xlsx
# Creation Date: 2024-05-30
# Modified Date: 2024-05-30
# Last Access Date: 2024-05-30
#
# File Name: 240601SOUTHSALARIES LEAVEBALANCES.CSV
# Creation Date: 2024-05-30
# Modified Date: 2024-05-30
# Last Access Date: 2024-05-30

# %%
#checking the files in the folder, there should be 12 excluding "employee_data_tidy"
most_recent_records = file_records.values()
for item in most_recent_records:
    print(item['File Name'])
    print()
# Out:
# 240601 NorthSalaries EmployeeList.xlsx
#
# 240601 NORTHSALARIES LEAVEBALANCES.CSV
#
# 240601 NorthSalaries TerminatedEmployees.xlsx
#
# 240601 NorthWages EmployeeList.xlsx
#
# 240601 NORTHWAGES LEAVEBALANCES.CSV
#
# 240601 NorthWages TerminatedEmployees.xlsx
#
# 240601 SouthSalaries EmployeeList.xlsx
#
# 240601 SouthSalaries TerminatedEmployees.xlsx
#
# 240601 SouthWages EmployeeList.xlsx
#
# 240601 SOUTHWAGES LEAVEBALANCES.CSV
#
# 240601 SouthWages TerminatedEmployees.xlsx
#
# 240601SOUTHSALARIES LEAVEBALANCES.CSV

# %%
#determine correct file types

for record in most_recent_records:
    lower_name = record["File Name"].lower()

    record["IsSalaries"] = True if "salaries" in lower_name else False
    record["IsWages"] = True if "wages" in lower_name else False
    record["IsNorth"] = True if "north" in lower_name else False
    record["IsSouth"] = True if "south" in lower_name else False
    record["IsTerminated"] = True if "terminated" in lower_name else False
    record["IsLeaveBalance"] = True if "balances" in lower_name else False

print("="*50)
for item in most_recent_records:
    for k,v in item.items():
        print(f"{k}:{v}")
    print("="*50)
# Out:
# ==================================================
# File Name:240601 NorthSalaries EmployeeList.xlsx
# Creation Date:2024-05-30
# Modified Date:2024-05-30
# Last Access Date:2024-05-30
# IsSalaries:True
# IsWages:False
# IsNorth:True
# IsSouth:False
# IsTerminated:False
# IsLeaveBalance:False
# ==================================================
# File Name:240601 NORTHSALARIES LEAVEBALANCES.CSV
# Creation Date:2024-05-30
# Modified Date:2024-05-30
# Last Access Date:2024-05-30
# IsSalaries:True
# IsWages:False
# IsNorth:True
# IsSouth:False
# IsTerminated:False
# IsLeaveBalance:True
# ==================================================
# File Name:240601 NorthSalaries TerminatedEmployees.xlsx
# Creation Date:2024-05-30
# Modified Date:2024-05-30
# Last Access Date:2024-05-30
# IsSalaries:True
# IsWages:False
# IsNorth:True
# IsSouth:False
# IsTerminated:True
# IsLeaveBalance:False
# ==================================================
# File Name:240601 NorthWages EmployeeList.xlsx
# Creation Date:2024-05-30
# Modified Date:2024-05-30
# Last Access Date:2024-05-30
# IsSalaries:False
# IsWages:True
# IsNorth:True
# IsSouth:False
# IsTerminated:False
# IsLeaveBalance:False
# ==================================================
# File Name:240601 NORTHWAGES LEAVEBALANCES.CSV
# Creation Date:2024-05-30
# Modified Date:2024-05-30
# Last Access Date:2024-05-30
# IsSalaries:False
# IsWages:True
# IsNorth:True
# IsSouth:False
# IsTerminated:False
# IsLeaveBalance:True
# ==================================================
# File Name:240601 NorthWages TerminatedEmployees.xlsx
# Creation Date:2024-05-30
# Modified Date:2024-05-30
# Last Access Date:2024-05-30
# IsSalaries:False
# IsWages:True
# IsNorth:True
# IsSouth:False
# IsTerminated:True
# IsLeaveBalance:False
# ==================================================
# File Name:240601 SouthSalaries EmployeeList.xlsx
# Creation Date:2024-05-30
# Modified Date:2024-05-30
# Last Access Date:2024-05-30
# IsSalaries:True
# IsWages:False
# IsNorth:False
# IsSouth:True
# IsTerminated:False
# IsLeaveBalance:False
# ==================================================
# File Name:240601 SouthSalaries TerminatedEmployees.xlsx
# Creation Date:2024-05-30
# Modified Date:2024-05-30
# Last Access Date:2024-05-30
# IsSalaries:True
# IsWages:False
# IsNorth:False
# IsSouth:True
# IsTerminated:True
# IsLeaveBalance:False
# ==================================================
# File Name:240601 SouthWages EmployeeList.xlsx
# Creation Date:2024-05-30
# Modified Date:2024-05-30
# Last Access Date:2024-05-30
# IsSalaries:False
# IsWages:True
# IsNorth:False
# IsSouth:True
# IsTerminated:False
# IsLeaveBalance:False
# ==================================================
# File Name:240601 SOUTHWAGES LEAVEBALANCES.CSV
# Creation Date:2024-05-30
# Modified Date:2024-05-30
# Last Access Date:2024-05-30
# IsSalaries:False
# IsWages:True
# IsNorth:False
# IsSouth:True
# IsTerminated:False
# IsLeaveBalance:True
# ==================================================
# File Name:240601 SouthWages TerminatedEmployees.xlsx
# Creation Date:2024-05-30
# Modified Date:2024-05-30
# Last Access Date:2024-05-30
# IsSalaries:False
# IsWages:True
# IsNorth:False
# IsSouth:True
# IsTerminated:True
# IsLeaveBalance:False
# ==================================================
# File Name:240601SOUTHSALARIES LEAVEBALANCES.CSV
# Creation Date:2024-05-30
# Modified Date:2024-05-30
# Last Access Date:2024-05-30
# IsSalaries:True
# IsWages:False
# IsNorth:False
# IsSouth:True
# IsTerminated:False
# IsLeaveBalance:True
# ==================================================

# %% [markdown]
# ### Combining and Processing files

# %%
def separate_files(records,south_or_north:str="IsSouth",salaried_or_waged:str = "IsWages",leave_filter:str='IsLeaveBalance',terminated_filter='IsTerminated') -> tuple[list,list,list]:
    """separates list of files into south/noth,waged/salaried, leave balanced and terminated"""
    for record in records:
        file = record["File Name"]
        if file == "employee_data_tidy.csv":
            continue
        #print(file)
        if record[south_or_north] and record[salaried_or_waged]: #record selection recuded to south/north or wages/salaried based on parameter        
            print(record)
            
            if record[leave_filter]:
                leave_balances_file = file

            elif record[terminated_filter]:
                terminated_file = file

            else:
                waged_or_salaried_file = file
                
    return waged_or_salaried_file,leave_balances_file,terminated_file

def add_name_key(df:pd.DataFrame,name_column:str="Name") -> pd.DataFrame:
    """add name key to dataframe"""
    df["Name_Key"] = df[name_column].str.replace(",","").str.replace(" ","").str.lower().str.lstrip().str.rstrip()
    return df

def table_to_html(df):
    html = df.to_html()
    # Write html to file
    text_file = open("index.html", "w")
    text_file.write(html)
    text_file.close()

def files_to_dataframe(file,leave_balances_file,terminated_file,engine='openpyxl',date_format='%d-%m-%Y') -> pd.DataFrame:
    """convert separated files into dataframe format"""
    file_df = pd.read_excel(file,skiprows=1,engine=engine,date_format=date_format,parse_dates=["Start Date","Birth Date","Visa Expiry"])
    file_df["Name"] = file_df["Name"].str.lstrip().str.rstrip()
    print(file_df["Fixed Term Expiry"])
    print(file_df.shape)
    ##add status information
    file_df["Status"] = "Active"
    #standardize name
    add_name_key(file_df, name_column="Name")
    print("main file read successfully!")
    print(file_df.columns)

    leave_df = pd.read_csv(leave_balances_file)
    print(leave_df.head())
    leave_df["Employee Full Name"] = leave_df["Employee Full Name"].str.lstrip().str.rstrip()
    add_name_key(leave_df, name_column="Employee Full Name")
    print("leave file read successfully!")
    print(leave_df.columns)
    print(leave_df.shape)

    terminated_df = pd.read_excel(terminated_file,skiprows=1,engine=engine,date_format=date_format,parse_dates=["Start Date","Birth Date","Finish Date","Fixed Term Expiry"])
    terminated_df["Status"] = "Inactive"
    terminated_df["Name"] = terminated_df["Name"].str.lstrip().str.rstrip()
    add_name_key(terminated_df, name_column="Name")
    print("terminated file read successfully!")
    print(terminated_df.shape)
    print(terminated_df.columns)
    #merge on Name_Key
    merged_df = file_df.merge(leave_df,left_on="Name_Key",right_on="Name_Key",how="inner")
    #concatendate active and inative staff
    concat_df = pd.concat([merged_df,terminated_df],axis=0)
    return concat_df

def add_region(df,modify_to:str='North Island'): 
    df["Region"] = modify_to
    return df

# %%
print("="*50)
print("South Waged")
waged_file,leave_balances_file,terminated_file = separate_files(most_recent_records)
print(waged_file,leave_balances_file,terminated_file,sep="\n")
south_waged = files_to_dataframe(waged_file,leave_balances_file,terminated_file)
#write an html table
add_region(south_waged, modify_to="South Island")

get_info(south_waged)
# Out:
# ==================================================
# South Waged
# {'File Name': '240601 SouthWages EmployeeList.xlsx', 'Creation Date': datetime.date(2024, 5, 30), 'Modified Date': datetime.date(2024, 5, 30), 'Last Access Date': datetime.date(2024, 5, 30), 'IsSalaries': False, 'IsWages': True, 'IsNorth': False, 'IsSouth': True, 'IsTerminated': False, 'IsLeaveBalance': False}
# {'File Name': '240601 SOUTHWAGES LEAVEBALANCES.CSV', 'Creation Date': datetime.date(2024, 5, 30), 'Modified Date': datetime.date(2024, 5, 30), 'Last Access Date': datetime.date(2024, 5, 30), 'IsSalaries': False, 'IsWages': True, 'IsNorth': False, 'IsSouth': True, 'IsTerminated': False, 'IsLeaveBalance': True}
# {'File Name': '240601 SouthWages TerminatedEmployees.xlsx', 'Creation Date': datetime.date(2024, 5, 30), 'Modified Date': datetime.date(2024, 5, 30), 'Last Access Date': datetime.date(2024, 5, 30), 'IsSalaries': False, 'IsWages': True, 'IsNorth': False, 'IsSouth': True, 'IsTerminated': True, 'IsLeaveBalance': False}
# 240601 SouthWages EmployeeList.xlsx
# 240601 SOUTHWAGES LEAVEBALANCES.CSV
# 240601 SouthWages TerminatedEmployees.xlsx
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# 30   NaN
# 31   NaN
# 32   NaN
# 33   NaN
# 34   NaN
# 35   NaN
# 36   NaN
# 37   NaN
# 38   NaN
# 39   NaN
# 40   NaN
# 41   NaN
# 42   NaN
# 43   NaN
# 44   NaN
# 45   NaN
# 46   NaN
# 47   NaN
# 48   NaN
# 49   NaN
# 50   NaN
# 51   NaN
# 52   NaN
# 53   NaN
# 54   NaN
# 55   NaN
# 56   NaN
# 57   NaN
# 58   NaN
# 59   NaN
# 60   NaN
# 61   NaN
# 62   NaN
# 63   NaN
# 64   NaN
# 65   NaN
# 66   NaN
# 67   NaN
# 68   NaN
# 69   NaN
# 70   NaN
# 71   NaN
# 72   NaN
# 73   NaN
# Name: Fixed Term Expiry, dtype: float64
# (74, 17)
# main file read successfully!
# Index(['Name', 'Alpha Code', 'Start Date', 'Department', 'Employment  Status',
#        'Salary/ Wage', 'Hours Worked', 'Birth Date', 'Occupation', 'Ethnicity',
#        'Visa Type', 'Visa Duration', 'Visa Expiry', 'EstimatedFixedTermExpiry',
#        'FixedTermAgreement', 'Fixed Term Expiry', 'Gender', 'Status',
#        'Name_Key'],
#       dtype='object')
#       Employee Full Name   Sick/Special Leave Balance   Holidays Balance
# 0   Abad  Arnold Sanguyo                          9.0              18.12
# 1     Acantilado  Richel                         19.0              15.26
# 2  Adlaon  Arthur Prieto                         10.0              11.90
# 3     Algar  Roy Anthony                          0.0               5.11
# 4   Anderson  Liam James                          9.0              14.00
# leave file read successfully!
# Index(['Employee Full Name', ' Sick/Special Leave Balance',
#        ' Holidays Balance', 'Name_Key'],
#       dtype='object')
# (74, 4)
# terminated file read successfully!
# (405, 17)
# Index(['Name', 'Alpha Code', 'Start Date', 'Department', 'Employment  Status',
#        'Salary/ Wage', 'Hours Worked', 'Birth Date', 'Occupation',
#        'Finish Date', 'Ethnicity', 'Visa Duration', 'Visa Type',
#        'Fixed Term Expiry', 'Gender', 'Status', 'Name_Key'],
#       dtype='object')
# ==================================================
# (479, 24)
#                     Name Alpha Code           Start Date  \
# 0   Abad, Arnold Sanguyo   ABAD      2012-09-27 00:00:00
# 1     Acantilado, Richel   ACANTILA  2015-01-08 00:00:00
# 2  Adlaon, Arthur Prieto   ADLAO001  2022-10-13 00:00:00
# 3     Algar, Roy Anthony   ALGAR     2011-09-12 00:00:00
# 4   Anderson, Liam James   ANDER001  2022-08-29 00:00:00
#
#                  Department Employment  Status Salary/ Wage  Hours Worked  \
# 0  22 - Projects Operations          Permanent     Wage              40.0
# 1  22 - Projects Operations          Permanent     Wage              40.0
# 2  22 - Projects Operations          Permanent     Wage              47.5
# 3  25 - Projects Management          Permanent     Wage              45.0
# 4  25 - Projects Management          Permanent     Wage              45.0
#
#             Birth Date                           Occupation  \
# 0  1977-10-08 00:00:00  Leading Hand
# 1  1977-01-24 00:00:00  Carpenter
# 2  1970-03-24 00:00:00  Carpenter
# 3  1973-12-02 00:00:00  Site Supervisor
# 4  1989-07-31 00:00:00  Site Supervisor
#
#                                            Ethnicity  ... FixedTermAgreement  \
# 0                                                ...  ...              False
# 1                                                ...  ...              False
# 2                                                ...  ...              False
# 3                                                ...  ...              False
# 4  NZ European                                   ...  ...              False
#
#   Fixed Term Expiry          Gender  Status            Name_Key  \
# 0               NaN  Male            Active   abadarnoldsanguyo
# 1               NaN  Male            Active    acantiladorichel
# 2               NaN  Male            Active  adlaonarthurprieto
# 3               NaN  Male            Active     algarroyanthony
# 4               NaN  Male            Active   andersonliamjames
#
#       Employee Full Name  Sick/Special Leave Balance  Holidays Balance  \
# 0   Abad  Arnold Sanguyo                         9.0             18.12
# 1     Acantilado  Richel                        19.0             15.26
# 2  Adlaon  Arthur Prieto                        10.0             11.90
# 3     Algar  Roy Anthony                         0.0              5.11
# 4   Anderson  Liam James                         9.0             14.00
#
#   Finish Date        Region
# 0         NaN  South Island
# 1         NaN  South Island
# 2         NaN  South Island
# 3         NaN  South Island
# 4         NaN  South Island
#
# [5 rows x 24 columns]
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 479 entries, 0 to 404
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name                         479 non-null    object
#  1   Alpha Code                   479 non-null    object
#  2   Start Date                   479 non-null    object
#  3   Department                   479 non-null    object
#  4   Employment  Status           479 non-null    object
#  5   Salary/ Wage                 479 non-null    object
#  6   Hours Worked                 479 non-null    float64
#  7   Birth Date                   474 non-null    object
#  8   Occupation                   479 non-null    object
#  9   Ethnicity                    479 non-null    object
#  10  Visa Type                    479 non-null    object
#  11  Visa Duration                479 non-null    object
#  12  Visa Expiry                  12 non-null     object
#  13  EstimatedFixedTermExpiry     74 non-null     object
#  14  FixedTermAgreement           74 non-null     object
#  15  Fixed Term Expiry            0 non-null      object
#  16  Gender                       479 non-null    object
#  17  Status                       479 non-null    object
#  18  Name_Key                     479 non-null    object
#  19  Employee Full Name           74 non-null     object
#  20   Sick/Special Leave Balance  74 non-null     float64
#  21   Holidays Balance            74 non-null     float64
#  22  Finish Date                  405 non-null    object
#  23  Region                       479 non-null    object
# dtypes: float64(3), object(21)
# memory usage: 93.6+ KB
# None
#
# ==================================================

# %%
south_waged.columns
# Out:
# Index(['Name', 'Alpha Code', 'Start Date', 'Department', 'Employment  Status',
#        'Salary/ Wage', 'Hours Worked', 'Birth Date', 'Occupation', 'Ethnicity',
#        'Visa Type', 'Visa Duration', 'Visa Expiry', 'EstimatedFixedTermExpiry',
#        'FixedTermAgreement', 'Fixed Term Expiry', 'Gender', 'Status',
#        'Name_Key', 'Employee Full Name', ' Sick/Special Leave Balance',
#        ' Holidays Balance', 'Finish Date', 'Region'],
#       dtype='object')

# %%
#north wages, filenames contain both north and wages

print("="*50)
print("North Waged")
north_waged_file,leave_balances_file,terminated_file = separate_files(most_recent_records,south_or_north="IsNorth",salaried_or_waged="IsWages")
north_waged = files_to_dataframe(north_waged_file,leave_balances_file,terminated_file)

add_region(north_waged,"North Island")
#adjust_departments(north_waged)

##final preprocessing
#for exited staff MYOB defaults the Cost Center to 1 - Leighs Christchurch.Modify the North Island wages to Auckland (by Default) or New Plymouth
#north_waged.loc[north_waged["Finish"] and [north_waged["Cost Centre"]] = "2 - Leighs Auckland"
get_info(north_waged)
# Out:
# ==================================================
# North Waged
# {'File Name': '240601 NorthWages EmployeeList.xlsx', 'Creation Date': datetime.date(2024, 5, 30), 'Modified Date': datetime.date(2024, 5, 30), 'Last Access Date': datetime.date(2024, 5, 30), 'IsSalaries': False, 'IsWages': True, 'IsNorth': True, 'IsSouth': False, 'IsTerminated': False, 'IsLeaveBalance': False}
# {'File Name': '240601 NORTHWAGES LEAVEBALANCES.CSV', 'Creation Date': datetime.date(2024, 5, 30), 'Modified Date': datetime.date(2024, 5, 30), 'Last Access Date': datetime.date(2024, 5, 30), 'IsSalaries': False, 'IsWages': True, 'IsNorth': True, 'IsSouth': False, 'IsTerminated': False, 'IsLeaveBalance': True}
# {'File Name': '240601 NorthWages TerminatedEmployees.xlsx', 'Creation Date': datetime.date(2024, 5, 30), 'Modified Date': datetime.date(2024, 5, 30), 'Last Access Date': datetime.date(2024, 5, 30), 'IsSalaries': False, 'IsWages': True, 'IsNorth': True, 'IsSouth': False, 'IsTerminated': True, 'IsLeaveBalance': False}
# 0           NaT
# 1    2025-02-28
# 2           NaT
# 3           NaT
# 4           NaT
# 5           NaT
# 6           NaT
# 7           NaT
# 8           NaT
# 9           NaT
# 10          NaT
# 11   2025-04-25
# 12   2025-02-28
# 13          NaT
# 14          NaT
# 15          NaT
# 16          NaT
# 17          NaT
# 18          NaT
# 19          NaT
# 20          NaT
# 21          NaT
# 22          NaT
# 23          NaT
# 24          NaT
# 25          NaT
# 26          NaT
# 27   2024-09-27
# 28          NaT
# 29   2024-06-28
# 30          NaT
# 31          NaT
# 32   2025-04-25
# 33   2024-06-28
# 34          NaT
# 35          NaT
# 36          NaT
# 37          NaT
# 38          NaT
# 39          NaT
# 40          NaT
# 41          NaT
# 42          NaT
# 43          NaT
# 44          NaT
# 45          NaT
# 46          NaT
# 47          NaT
# 48          NaT
# 49          NaT
# 50          NaT
# 51          NaT
# 52          NaT
# 53          NaT
# 54          NaT
# 55          NaT
# 56          NaT
# 57          NaT
# 58          NaT
# 59          NaT
# 60          NaT
# 61          NaT
# 62          NaT
# 63          NaT
# 64          NaT
# 65   2025-02-28
# 66          NaT
# Name: Fixed Term Expiry, dtype: datetime64[ns]
# (67, 17)
# main file read successfully!
# Index(['Name', 'Alpha Code', 'Start Date', 'Department', 'Employment  Status',
#        'Salary/ Wage', 'Hours Worked', 'Birth Date', 'Occupation', 'Ethnicity',
#        'Visa Type', 'Visa Duration', 'Visa Expiry', 'EstimatedFixedTermExpiry',
#        'FixedTermAgreement', 'Fixed Term Expiry', 'Gender', 'Status',
#        'Name_Key'],
#       dtype='object')
#           Employee Full Name   Sick/Special Leave Balance   Holidays Balance
# 0       Albio  Joseph Garcia                          8.0               8.82
# 1  Alexander  Michael Graeme                          6.0               2.82
# 2   Ampongan  Moises Jr Oraa                          2.0               7.82
# 3      Anonuevo  Lito Burgos                         19.0              16.12
# 4             Anonuevo  Joel                         12.0              16.61
# leave file read successfully!
# Index(['Employee Full Name', ' Sick/Special Leave Balance',
#        ' Holidays Balance', 'Name_Key'],
#       dtype='object')
# (67, 4)
# terminated file read successfully!
# (108, 17)
# Index(['Name', 'Alpha Code', 'Start Date', 'Department', 'Employment  Status',
#        'Salary/ Wage', 'Hours Worked', 'Birth Date', 'Occupation',
#        'Finish Date', 'Ethnicity', 'Visa Duration', 'Visa Type',
#        'Fixed Term Expiry', 'Gender', 'Status', 'Name_Key'],
#       dtype='object')
# ==================================================
# (175, 24)
#                         Name Alpha Code           Start Date  \
# 0       Albio, Joseph Garcia   ALBIO     2023-02-24 00:00:00
# 1  Alexander, Michael Graeme   ALEXANDE  2023-10-16 00:00:00
# 2   Ampongan, Moises Jr Oraa   AMPONGAN  2023-03-21 00:00:00
# 3      Anonuevo, Lito Burgos   ANONU001  2013-05-08 00:00:00
# 4             Anonuevo, Joel   ANONUEVO  2014-06-06 00:00:00
#
#                  Department Employment  Status Salary/ Wage  Hours Worked  \
# 0  22 - Projects Operations          Permanent     Wage              46.5
# 1  22 - Projects Operations          Permanent     Wage              45.0
# 2  22 - Projects Operations          Permanent     Wage              46.5
# 3  22 - Projects Operations          Permanent     Wage              40.0
# 4  22 - Projects Operations          Permanent     Wage              40.0
#
#             Birth Date                           Occupation  \
# 0  1987-11-16 00:00:00  Carpenter
# 1  1964-11-23 00:00:00  Gateman
# 2  1987-06-13 00:00:00  Carpenter
# 3  1975-01-25 00:00:00  Leading Hand
# 4  1973-05-27 00:00:00  Carpenter
#
#                                            Ethnicity  ... FixedTermAgreement  \
# 0  Filipino                                      ...  ...              False
# 1  NZ European                                   ...  ...               True
# 2  Filipino                                      ...  ...              False
# 3                                                ...  ...              False
# 4                                                ...  ...              False
#
#   Fixed Term Expiry          Gender  Status                Name_Key  \
# 0               NaT  Male            Active       albiojosephgarcia
# 1        2025-02-28  Male            Active  alexandermichaelgraeme
# 2               NaT  Male            Active    amponganmoisesjroraa
# 3               NaT  Male            Active      anonuevolitoburgos
# 4               NaT  Male            Active            anonuevojoel
#
#           Employee Full Name  Sick/Special Leave Balance  Holidays Balance  \
# 0       Albio  Joseph Garcia                         8.0              8.82
# 1  Alexander  Michael Graeme                         6.0              2.82
# 2   Ampongan  Moises Jr Oraa                         2.0              7.82
# 3      Anonuevo  Lito Burgos                        19.0             16.12
# 4             Anonuevo  Joel                        12.0             16.61
#
#   Finish Date        Region
# 0         NaN  North Island
# 1         NaN  North Island
# 2         NaN  North Island
# 3         NaN  North Island
# 4         NaN  North Island
#
# [5 rows x 24 columns]
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 175 entries, 0 to 107
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name                         175 non-null    object
#  1   Alpha Code                   175 non-null    object
#  2   Start Date                   175 non-null    object
#  3   Department                   175 non-null    object
#  4   Employment  Status           175 non-null    object
#  5   Salary/ Wage                 175 non-null    object
#  6   Hours Worked                 175 non-null    float64
#  7   Birth Date                   174 non-null    object
#  8   Occupation                   175 non-null    object
#  9   Ethnicity                    175 non-null    object
#  10  Visa Type                    175 non-null    object
#  11  Visa Duration                175 non-null    object
#  12  Visa Expiry                  39 non-null     object
#  13  EstimatedFixedTermExpiry     67 non-null     object
#  14  FixedTermAgreement           67 non-null     object
#  15  Fixed Term Expiry            8 non-null      datetime64[ns]
#  16  Gender                       175 non-null    object
#  17  Status                       175 non-null    object
#  18  Name_Key                     175 non-null    object
#  19  Employee Full Name           67 non-null     object
#  20   Sick/Special Leave Balance  67 non-null     float64
#  21   Holidays Balance            67 non-null     float64
#  22  Finish Date                  107 non-null    object
#  23  Region                       175 non-null    object
# dtypes: datetime64[ns](1), float64(3), object(20)
# memory usage: 34.2+ KB
# None
#
# ==================================================

# %%
south_waged.columns
# Out:
# Index(['Name', 'Alpha Code', 'Start Date', 'Department', 'Employment  Status',
#        'Salary/ Wage', 'Hours Worked', 'Birth Date', 'Occupation', 'Ethnicity',
#        'Visa Type', 'Visa Duration', 'Visa Expiry', 'EstimatedFixedTermExpiry',
#        'FixedTermAgreement', 'Fixed Term Expiry', 'Gender', 'Status',
#        'Name_Key', 'Employee Full Name', ' Sick/Special Leave Balance',
#        ' Holidays Balance', 'Finish Date', 'Region'],
#       dtype='object')

# %%
#concatenate north and south for waged
waged = pd.concat([south_waged,north_waged])
waged.head()
# Out:
# C:\Users\alex.jefferies\AppData\Local\Temp\ipykernel_16000\334188665.py:2: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   waged = pd.concat([south_waged,north_waged])
#                     Name Alpha Code           Start Date  \
# 0   Abad, Arnold Sanguyo   ABAD      2012-09-27 00:00:00
# 1     Acantilado, Richel   ACANTILA  2015-01-08 00:00:00
# 2  Adlaon, Arthur Prieto   ADLAO001  2022-10-13 00:00:00
# 3     Algar, Roy Anthony   ALGAR     2011-09-12 00:00:00
# 4   Anderson, Liam James   ANDER001  2022-08-29 00:00:00
#
#                  Department Employment  Status Salary/ Wage  Hours Worked  \
# 0  22 - Projects Operations          Permanent     Wage              40.0
# 1  22 - Projects Operations          Permanent     Wage              40.0
# 2  22 - Projects Operations          Permanent     Wage              47.5
# 3  25 - Projects Management          Permanent     Wage              45.0
# 4  25 - Projects Management          Permanent     Wage              45.0
#
#             Birth Date                           Occupation  \
# 0  1977-10-08 00:00:00  Leading Hand
# 1  1977-01-24 00:00:00  Carpenter
# 2  1970-03-24 00:00:00  Carpenter
# 3  1973-12-02 00:00:00  Site Supervisor
# 4  1989-07-31 00:00:00  Site Supervisor
#
#                                            Ethnicity  ... FixedTermAgreement  \
# 0                                                ...  ...              False
# 1                                                ...  ...              False
# 2                                                ...  ...              False
# 3                                                ...  ...              False
# 4  NZ European                                   ...  ...              False
#
#   Fixed Term Expiry          Gender  Status            Name_Key  \
# 0               NaT  Male            Active   abadarnoldsanguyo
# 1               NaT  Male            Active    acantiladorichel
# 2               NaT  Male            Active  adlaonarthurprieto
# 3               NaT  Male            Active     algarroyanthony
# 4               NaT  Male            Active   andersonliamjames
#
#       Employee Full Name  Sick/Special Leave Balance  Holidays Balance  \
# 0   Abad  Arnold Sanguyo                         9.0             18.12
# 1     Acantilado  Richel                        19.0             15.26
# 2  Adlaon  Arthur Prieto                        10.0             11.90
# 3     Algar  Roy Anthony                         0.0              5.11
# 4   Anderson  Liam James                         9.0             14.00
#
#   Finish Date        Region
# 0         NaN  South Island
# 1         NaN  South Island
# 2         NaN  South Island
# 3         NaN  South Island
# 4         NaN  South Island
#
# [5 rows x 24 columns]

# %%
#fixed term dates not parsed 
#join for leave balances not working
missing_info(waged)
#missing_info(waged.query("Status == 'Active'"))
#waged.to_csv("waged_check.csv")
# Out:
#                              missing_count  missing_ratio
# Name                                     0       0.000000
# Alpha Code                               0       0.000000
# Start Date                               0       0.000000
# Department                               0       0.000000
# Employment  Status                       0       0.000000
# Salary/ Wage                             0       0.000000
# Hours Worked                             0       0.000000
# Birth Date                               6       0.009174
# Occupation                               0       0.000000
# Ethnicity                                0       0.000000
# Visa Type                                0       0.000000
# Visa Duration                            0       0.000000
# Visa Expiry                            603       0.922018
# EstimatedFixedTermExpiry               513       0.784404
# FixedTermAgreement                     513       0.784404
# Fixed Term Expiry                      646       0.987768
# Gender                                   0       0.000000
# Status                                   0       0.000000
# Name_Key                                 0       0.000000
# Employee Full Name                     513       0.784404
#  Sick/Special Leave Balance            513       0.784404
#  Holidays Balance                      513       0.784404
# Finish Date                            142       0.217125
# Region                                   0       0.000000

# %%
#note. completely missing leave balances for inactive employees is to be expected 
missing_info(waged.query("Status != 'Active'"))
# Out:
#                              missing_count  missing_ratio
# Name                                     0       0.000000
# Alpha Code                               0       0.000000
# Start Date                               0       0.000000
# Department                               0       0.000000
# Employment  Status                       0       0.000000
# Salary/ Wage                             0       0.000000
# Hours Worked                             0       0.000000
# Birth Date                               6       0.011696
# Occupation                               0       0.000000
# Ethnicity                                0       0.000000
# Visa Type                                0       0.000000
# Visa Duration                            0       0.000000
# Visa Expiry                            513       1.000000
# EstimatedFixedTermExpiry               513       1.000000
# FixedTermAgreement                     513       1.000000
# Fixed Term Expiry                      513       1.000000
# Gender                                   0       0.000000
# Status                                   0       0.000000
# Name_Key                                 0       0.000000
# Employee Full Name                     513       1.000000
#  Sick/Special Leave Balance            513       1.000000
#  Holidays Balance                      513       1.000000
# Finish Date                              1       0.001949
# Region                                   0       0.000000

# %%
waged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 654 entries, 0 to 107
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name                         654 non-null    object
#  1   Alpha Code                   654 non-null    object
#  2   Start Date                   654 non-null    object
#  3   Department                   654 non-null    object
#  4   Employment  Status           654 non-null    object
#  5   Salary/ Wage                 654 non-null    object
#  6   Hours Worked                 654 non-null    float64
#  7   Birth Date                   648 non-null    object
#  8   Occupation                   654 non-null    object
#  9   Ethnicity                    654 non-null    object
#  10  Visa Type                    654 non-null    object
#  11  Visa Duration                654 non-null    object
#  12  Visa Expiry                  51 non-null     object
#  13  EstimatedFixedTermExpiry     141 non-null    object
#  14  FixedTermAgreement           141 non-null    object
#  15  Fixed Term Expiry            8 non-null      datetime64[ns]
#  16  Gender                       654 non-null    object
#  17  Status                       654 non-null    object
#  18  Name_Key                     654 non-null    object
#  19  Employee Full Name           141 non-null    object
#  20   Sick/Special Leave Balance  141 non-null    float64
#  21   Holidays Balance            141 non-null    float64
#  22  Finish Date                  512 non-null    object
#  23  Region                       654 non-null    object
# dtypes: datetime64[ns](1), float64(3), object(20)
# memory usage: 127.7+ KB

# %%
print("="*50)
print("South Salaried")
south_salaried_file,leave_balances_file,terminated_file = separate_files(most_recent_records,south_or_north="IsSouth",salaried_or_waged="IsSalaries")
south_salaried = files_to_dataframe(south_salaried_file,leave_balances_file,terminated_file)
add_region(south_salaried,"South Island")

get_info(south_salaried)
# Out:
# ==================================================
# South Salaried
# {'File Name': '240601 SouthSalaries EmployeeList.xlsx', 'Creation Date': datetime.date(2024, 5, 30), 'Modified Date': datetime.date(2024, 5, 30), 'Last Access Date': datetime.date(2024, 5, 30), 'IsSalaries': True, 'IsWages': False, 'IsNorth': False, 'IsSouth': True, 'IsTerminated': False, 'IsLeaveBalance': False}
# {'File Name': '240601 SouthSalaries TerminatedEmployees.xlsx', 'Creation Date': datetime.date(2024, 5, 30), 'Modified Date': datetime.date(2024, 5, 30), 'Last Access Date': datetime.date(2024, 5, 30), 'IsSalaries': True, 'IsWages': False, 'IsNorth': False, 'IsSouth': True, 'IsTerminated': True, 'IsLeaveBalance': False}
# {'File Name': '240601SOUTHSALARIES LEAVEBALANCES.CSV', 'Creation Date': datetime.date(2024, 5, 30), 'Modified Date': datetime.date(2024, 5, 30), 'Last Access Date': datetime.date(2024, 5, 30), 'IsSalaries': True, 'IsWages': False, 'IsNorth': False, 'IsSouth': True, 'IsTerminated': False, 'IsLeaveBalance': True}
# 0           NaT
# 1           NaT
# 2           NaT
# 3           NaT
# 4    2024-05-10
# 5           NaT
# 6           NaT
# 7           NaT
# 8           NaT
# 9           NaT
# 10          NaT
# 11          NaT
# 12          NaT
# 13          NaT
# 14          NaT
# 15          NaT
# 16          NaT
# 17          NaT
# 18          NaT
# 19          NaT
# 20          NaT
# 21          NaT
# 22          NaT
# 23          NaT
# 24          NaT
# 25          NaT
# 26          NaT
# 27          NaT
# 28          NaT
# 29          NaT
# 30          NaT
# 31          NaT
# 32          NaT
# 33          NaT
# 34          NaT
# 35          NaT
# 36          NaT
# 37          NaT
# 38          NaT
# 39          NaT
# 40          NaT
# 41          NaT
# 42          NaT
# 43          NaT
# 44          NaT
# 45          NaT
# 46          NaT
# 47          NaT
# 48          NaT
# 49          NaT
# 50          NaT
# 51          NaT
# 52          NaT
# 53          NaT
# 54          NaT
# 55          NaT
# 56          NaT
# 57          NaT
# 58          NaT
# 59          NaT
# 60          NaT
# 61          NaT
# 62          NaT
# 63          NaT
# 64          NaT
# 65          NaT
# 66          NaT
# 67          NaT
# 68          NaT
# 69          NaT
# 70          NaT
# 71          NaT
# 72          NaT
# 73          NaT
# 74          NaT
# 75          NaT
# 76          NaT
# 77          NaT
# 78          NaT
# 79          NaT
# 80          NaT
# 81   2025-10-07
# 82          NaT
# 83          NaT
# 84          NaT
# 85          NaT
# 86          NaT
# 87          NaT
# 88          NaT
# 89          NaT
# 90          NaT
# 91          NaT
# Name: Fixed Term Expiry, dtype: datetime64[ns]
# (92, 17)
# main file read successfully!
# Index(['Name', 'Alpha Code', 'Start Date', 'Department', 'Employment  Status',
#        'Salary/ Wage', 'Hours Worked', 'Birth Date', 'Occupation', 'Ethnicity',
#        'Visa Type', 'Visa Duration', 'Visa Expiry', 'EstimatedFixedTermExpiry',
#        'FixedTermAgreement', 'Fixed Term Expiry', 'Gender', 'Status',
#        'Name_Key'],
#       dtype='object')
#           Employee Full Name   Sick/Special Leave Balance   Holidays Balance
# 0    Aitcheson  Shane Andrew                        17.53               4.70
# 1             Antrobus  Dean                        11.20               7.84
# 2       Aston  Stephen James                        10.00              11.84
# 3  Baggstrom  Kimberley Dawn                         9.00               3.82
# 4         Baker  Anthony Ian                         0.00               2.23
# leave file read successfully!
# Index(['Employee Full Name', ' Sick/Special Leave Balance',
#        ' Holidays Balance', 'Name_Key'],
#       dtype='object')
# (92, 4)
# terminated file read successfully!
# (195, 17)
# Index(['Name', 'Alpha Code', 'Start Date', 'Department', 'Employment  Status',
#        'Salary/ Wage', 'Hours Worked', 'Birth Date', 'Occupation',
#        'Finish Date', 'Ethnicity', 'Visa Duration', 'Visa Type',
#        'Fixed Term Expiry', 'Gender', 'Status', 'Name_Key'],
#       dtype='object')
# ==================================================
# (287, 24)
#                         Name Alpha Code           Start Date  \
# 0    Aitcheson, Shane Andrew   AITCHESO  2015-01-12 00:00:00
# 1             Antrobus, Dean   ANTRO001  2021-01-11 00:00:00
# 2       Aston, Stephen James   ASTON     2023-10-30 00:00:00
# 3  Baggstrom, Kimberley Dawn   BAGGSTRO  2023-09-07 00:00:00
# 4         Baker, Anthony Ian   BAKER001  2024-01-22 00:00:00
#
#                  Department Employment  Status Salary/ Wage  Hours Worked  \
# 0  25 - Projects Management          Permanent     Salary            45.0
# 1  23 - Projects Commercial          Permanent     Salary            45.0
# 2  25 - Projects Management          Permanent     Salary            45.0
# 3       13 - Administration          Permanent     Salary            40.0
# 4  30 - External Consultant          Permanent     Salary            40.0
#
#             Birth Date                           Occupation  \
# 0  1985-09-11 00:00:00  Project Manager
# 1  1969-01-29 00:00:00  Senior Quantity Surveyor
# 2  1980-07-16 00:00:00  Site Manager
# 3  1990-05-19 00:00:00  Regional Management Team Administra
# 4  1983-11-18 00:00:00  Job Pac Consultant
#
#                                            Ethnicity  ... FixedTermAgreement  \
# 0                                                ...  ...              False
# 1                                                ...  ...              False
# 2  British                                       ...  ...              False
# 3  NZ Maori, European                            ...  ...              False
# 4  NZ European                                   ...  ...               True
#
#   Fixed Term Expiry          Gender  Status                Name_Key  \
# 0               NaT  Male            Active    aitchesonshaneandrew
# 1               NaT  Male            Active            antrobusdean
# 2               NaT  Male            Active       astonstephenjames
# 3               NaT  Female          Active  baggstromkimberleydawn
# 4        2024-05-10  Male            Active         bakeranthonyian
#
#           Employee Full Name  Sick/Special Leave Balance  Holidays Balance  \
# 0    Aitcheson  Shane Andrew                       17.53              4.70
# 1             Antrobus  Dean                       11.20              7.84
# 2       Aston  Stephen James                       10.00             11.84
# 3  Baggstrom  Kimberley Dawn                        9.00              3.82
# 4         Baker  Anthony Ian                        0.00              2.23
#
#   Finish Date        Region
# 0         NaN  South Island
# 1         NaN  South Island
# 2         NaN  South Island
# 3         NaN  South Island
# 4         NaN  South Island
#
# [5 rows x 24 columns]
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 287 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name                         287 non-null    object
#  1   Alpha Code                   287 non-null    object
#  2   Start Date                   287 non-null    object
#  3   Department                   287 non-null    object
#  4   Employment  Status           287 non-null    object
#  5   Salary/ Wage                 287 non-null    object
#  6   Hours Worked                 287 non-null    float64
#  7   Birth Date                   286 non-null    object
#  8   Occupation                   287 non-null    object
#  9   Ethnicity                    287 non-null    object
#  10  Visa Type                    287 non-null    object
#  11  Visa Duration                287 non-null    object
#  12  Visa Expiry                  1 non-null      object
#  13  EstimatedFixedTermExpiry     92 non-null     object
#  14  FixedTermAgreement           92 non-null     object
#  15  Fixed Term Expiry            2 non-null      datetime64[ns]
#  16  Gender                       287 non-null    object
#  17  Status                       287 non-null    object
#  18  Name_Key                     287 non-null    object
#  19  Employee Full Name           92 non-null     object
#  20   Sick/Special Leave Balance  92 non-null     float64
#  21   Holidays Balance            92 non-null     float64
#  22  Finish Date                  195 non-null    object
#  23  Region                       287 non-null    object
# dtypes: datetime64[ns](1), float64(3), object(20)
# memory usage: 56.1+ KB
# None
#
# ==================================================

# %%
print("="*50)
print("North Salaried")
north_salaried_file,leave_balances_file,terminated_file = separate_files(most_recent_records,south_or_north="IsNorth",salaried_or_waged="IsSalaries")
north_salaried = files_to_dataframe(north_salaried_file,leave_balances_file,terminated_file)

add_region(north_salaried,"North Island")
get_info(north_salaried)
# Out:
# ==================================================
# North Salaried
# {'File Name': '240601 NorthSalaries EmployeeList.xlsx', 'Creation Date': datetime.date(2024, 5, 30), 'Modified Date': datetime.date(2024, 5, 30), 'Last Access Date': datetime.date(2024, 5, 30), 'IsSalaries': True, 'IsWages': False, 'IsNorth': True, 'IsSouth': False, 'IsTerminated': False, 'IsLeaveBalance': False}
# {'File Name': '240601 NORTHSALARIES LEAVEBALANCES.CSV', 'Creation Date': datetime.date(2024, 5, 30), 'Modified Date': datetime.date(2024, 5, 30), 'Last Access Date': datetime.date(2024, 5, 30), 'IsSalaries': True, 'IsWages': False, 'IsNorth': True, 'IsSouth': False, 'IsTerminated': False, 'IsLeaveBalance': True}
# {'File Name': '240601 NorthSalaries TerminatedEmployees.xlsx', 'Creation Date': datetime.date(2024, 5, 30), 'Modified Date': datetime.date(2024, 5, 30), 'Last Access Date': datetime.date(2024, 5, 30), 'IsSalaries': True, 'IsWages': False, 'IsNorth': True, 'IsSouth': False, 'IsTerminated': True, 'IsLeaveBalance': False}
# 0           NaT
# 1    2025-05-30
# 2           NaT
# 3    2025-02-28
# 4    2025-04-25
# 5           NaT
# 6    2025-03-28
# 7           NaT
# 8           NaT
# 9           NaT
# 10          NaT
# 11          NaT
# 12          NaT
# 13   2025-07-07
# 14   2024-12-20
# 15          NaT
# 16   2025-04-25
# 17          NaT
# 18   2024-11-29
# 19   2025-05-30
# 20          NaT
# 21          NaT
# 22   2025-07-07
# 23          NaT
# 24   2025-04-25
# 25          NaT
# 26          NaT
# 27          NaT
# 28   2025-04-26
# 29   2025-04-25
# 30   2025-04-25
# 31   2025-02-28
# 32          NaT
# 33          NaT
# 34          NaT
# 35   2024-12-20
# 36          NaT
# 37          NaT
# 38          NaT
# 39          NaT
# 40   2025-06-30
# 41   2025-05-30
# 42   2024-12-20
# 43          NaT
# 44          NaT
# 45   2024-08-09
# 46          NaT
# 47          NaT
# 48          NaT
# 49          NaT
# 50          NaT
# 51          NaT
# 52          NaT
# 53          NaT
# 54          NaT
# 55          NaT
# 56   2025-02-28
# 57          NaT
# 58          NaT
# 59   2024-11-29
# 60          NaT
# 61          NaT
# 62          NaT
# Name: Fixed Term Expiry, dtype: datetime64[ns]
# (63, 17)
# main file read successfully!
# Index(['Name', 'Alpha Code', 'Start Date', 'Department', 'Employment  Status',
#        'Salary/ Wage', 'Hours Worked', 'Birth Date', 'Occupation', 'Ethnicity',
#        'Visa Type', 'Visa Duration', 'Visa Expiry', 'EstimatedFixedTermExpiry',
#        'FixedTermAgreement', 'Fixed Term Expiry', 'Gender', 'Status',
#        'Name_Key'],
#       dtype='object')
#              Employee Full Name   Sick/Special Leave Balance  \
# 0  Alombro  Allan Jesus Benitez                         9.00
# 1               Astashkin  Ivan                         0.00
# 2       Baranyai  Damian Miklos                         8.33
# 3           Barnes  Stuart Ross                        10.00
# 4             Bence  Gary Peter                        20.00
#
#     Holidays Balance
# 0               8.82
# 1               3.78
# 2              12.77
# 3               6.82
# 4               5.41
# leave file read successfully!
# Index(['Employee Full Name', ' Sick/Special Leave Balance',
#        ' Holidays Balance', 'Name_Key'],
#       dtype='object')
# (63, 4)
# terminated file read successfully!
# (186, 17)
# Index(['Name', 'Alpha Code', 'Start Date', 'Department', 'Employment  Status',
#        'Salary/ Wage', 'Hours Worked', 'Birth Date', 'Occupation',
#        'Finish Date', 'Ethnicity', 'Visa Duration', 'Visa Type',
#        'Fixed Term Expiry', 'Gender', 'Status', 'Name_Key'],
#       dtype='object')
# ==================================================
# (249, 24)
#                            Name Alpha Code           Start Date  \
# 0  Alombro, Allan Jesus Benitez   ALOMBRO   2023-01-23 00:00:00
# 1               Astashkin, Ivan   ASTASHKI  2024-03-25 00:00:00
# 2       Baranyai, Damian Miklos   BARANYAI  2021-11-29 00:00:00
# 3           Barnes, Stuart Ross   BARNES    2023-09-18 00:00:00
# 4             Bence, Gary Peter   BENCE     2021-04-19 00:00:00
#
#                   Department Employment  Status Salary/ Wage  Hours Worked  \
# 0   25 - Projects Management          Permanent     Salary              45
# 1   25 - Projects Management          Permanent     Salary              45
# 2  26 - Future Leaders Progr          Permanent     Salary              45
# 3   25 - Projects Management          Permanent     Salary              45
# 4   23 - Projects Commercial          Permanent     Salary              45
#
#             Birth Date                           Occupation  \
# 0  1971-02-04 00:00:00  Site Manager
# 1  1990-08-24 00:00:00  Site Supervisor
# 2  1998-01-18 00:00:00  Building Services Coordinator
# 3  1985-12-20 00:00:00  Site Manager
# 4  1960-10-07 00:00:00  Senior Quantity Surveyor
#
#                                            Ethnicity  ... FixedTermAgreement  \
# 0  Filipino                                      ...  ...              False
# 1  European                                      ...  ...               True
# 2                                                ...  ...              False
# 3  NZ European                                   ...  ...               True
# 4                                                ...  ...               True
#
#   Fixed Term Expiry          Gender  Status                  Name_Key  \
# 0               NaT  Male            Active  alombroallanjesusbenitez
# 1        2025-05-30  Male            Active             astashkinivan
# 2               NaT  Male            Active      baranyaidamianmiklos
# 3        2025-02-28  Male            Active          barnesstuartross
# 4        2025-04-25  Male            Active            bencegarypeter
#
#              Employee Full Name  Sick/Special Leave Balance  Holidays Balance  \
# 0  Alombro  Allan Jesus Benitez                        9.00              8.82
# 1               Astashkin  Ivan                        0.00              3.78
# 2       Baranyai  Damian Miklos                        8.33             12.77
# 3           Barnes  Stuart Ross                       10.00              6.82
# 4             Bence  Gary Peter                       20.00              5.41
#
#   Finish Date        Region
# 0         NaN  North Island
# 1         NaN  North Island
# 2         NaN  North Island
# 3         NaN  North Island
# 4         NaN  North Island
#
# [5 rows x 24 columns]
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 249 entries, 0 to 185
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name                         249 non-null    object
#  1   Alpha Code                   249 non-null    object
#  2   Start Date                   249 non-null    object
#  3   Department                   249 non-null    object
#  4   Employment  Status           249 non-null    object
#  5   Salary/ Wage                 249 non-null    object
#  6   Hours Worked                 249 non-null    int64
#  7   Birth Date                   249 non-null    object
#  8   Occupation                   249 non-null    object
#  9   Ethnicity                    249 non-null    object
#  10  Visa Type                    249 non-null    object
#  11  Visa Duration                249 non-null    object
#  12  Visa Expiry                  6 non-null      object
#  13  EstimatedFixedTermExpiry     63 non-null     object
#  14  FixedTermAgreement           63 non-null     object
#  15  Fixed Term Expiry            22 non-null     datetime64[ns]
#  16  Gender                       249 non-null    object
#  17  Status                       249 non-null    object
#  18  Name_Key                     249 non-null    object
#  19  Employee Full Name           63 non-null     object
#  20   Sick/Special Leave Balance  63 non-null     float64
#  21   Holidays Balance            63 non-null     float64
#  22  Finish Date                  186 non-null    object
#  23  Region                       249 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(20)
# memory usage: 48.6+ KB
# None
#
# ==================================================

# %%
north_salaried.head()
# Out:
#                            Name Alpha Code           Start Date  \
# 0  Alombro, Allan Jesus Benitez   ALOMBRO   2023-01-23 00:00:00
# 1               Astashkin, Ivan   ASTASHKI  2024-03-25 00:00:00
# 2       Baranyai, Damian Miklos   BARANYAI  2021-11-29 00:00:00
# 3           Barnes, Stuart Ross   BARNES    2023-09-18 00:00:00
# 4             Bence, Gary Peter   BENCE     2021-04-19 00:00:00
#
#                   Department Employment  Status Salary/ Wage  Hours Worked  \
# 0   25 - Projects Management          Permanent     Salary              45
# 1   25 - Projects Management          Permanent     Salary              45
# 2  26 - Future Leaders Progr          Permanent     Salary              45
# 3   25 - Projects Management          Permanent     Salary              45
# 4   23 - Projects Commercial          Permanent     Salary              45
#
#             Birth Date                           Occupation  \
# 0  1971-02-04 00:00:00  Site Manager
# 1  1990-08-24 00:00:00  Site Supervisor
# 2  1998-01-18 00:00:00  Building Services Coordinator
# 3  1985-12-20 00:00:00  Site Manager
# 4  1960-10-07 00:00:00  Senior Quantity Surveyor
#
#                                            Ethnicity  ... FixedTermAgreement  \
# 0  Filipino                                      ...  ...              False
# 1  European                                      ...  ...               True
# 2                                                ...  ...              False
# 3  NZ European                                   ...  ...               True
# 4                                                ...  ...               True
#
#   Fixed Term Expiry          Gender  Status                  Name_Key  \
# 0               NaT  Male            Active  alombroallanjesusbenitez
# 1        2025-05-30  Male            Active             astashkinivan
# 2               NaT  Male            Active      baranyaidamianmiklos
# 3        2025-02-28  Male            Active          barnesstuartross
# 4        2025-04-25  Male            Active            bencegarypeter
#
#              Employee Full Name  Sick/Special Leave Balance  Holidays Balance  \
# 0  Alombro  Allan Jesus Benitez                        9.00              8.82
# 1               Astashkin  Ivan                        0.00              3.78
# 2       Baranyai  Damian Miklos                        8.33             12.77
# 3           Barnes  Stuart Ross                       10.00              6.82
# 4             Bence  Gary Peter                       20.00              5.41
#
#   Finish Date        Region
# 0         NaN  North Island
# 1         NaN  North Island
# 2         NaN  North Island
# 3         NaN  North Island
# 4         NaN  North Island
#
# [5 rows x 24 columns]

# %%
#concatenate north and south for salaried
salaried = pd.concat([south_salaried,north_salaried])
salaried.head()
# Out:
#                         Name Alpha Code           Start Date  \
# 0    Aitcheson, Shane Andrew   AITCHESO  2015-01-12 00:00:00
# 1             Antrobus, Dean   ANTRO001  2021-01-11 00:00:00
# 2       Aston, Stephen James   ASTON     2023-10-30 00:00:00
# 3  Baggstrom, Kimberley Dawn   BAGGSTRO  2023-09-07 00:00:00
# 4         Baker, Anthony Ian   BAKER001  2024-01-22 00:00:00
#
#                  Department Employment  Status Salary/ Wage  Hours Worked  \
# 0  25 - Projects Management          Permanent     Salary            45.0
# 1  23 - Projects Commercial          Permanent     Salary            45.0
# 2  25 - Projects Management          Permanent     Salary            45.0
# 3       13 - Administration          Permanent     Salary            40.0
# 4  30 - External Consultant          Permanent     Salary            40.0
#
#             Birth Date                           Occupation  \
# 0  1985-09-11 00:00:00  Project Manager
# 1  1969-01-29 00:00:00  Senior Quantity Surveyor
# 2  1980-07-16 00:00:00  Site Manager
# 3  1990-05-19 00:00:00  Regional Management Team Administra
# 4  1983-11-18 00:00:00  Job Pac Consultant
#
#                                            Ethnicity  ... FixedTermAgreement  \
# 0                                                ...  ...              False
# 1                                                ...  ...              False
# 2  British                                       ...  ...              False
# 3  NZ Maori, European                            ...  ...              False
# 4  NZ European                                   ...  ...               True
#
#   Fixed Term Expiry          Gender  Status                Name_Key  \
# 0               NaT  Male            Active    aitchesonshaneandrew
# 1               NaT  Male            Active            antrobusdean
# 2               NaT  Male            Active       astonstephenjames
# 3               NaT  Female          Active  baggstromkimberleydawn
# 4        2024-05-10  Male            Active         bakeranthonyian
#
#           Employee Full Name  Sick/Special Leave Balance  Holidays Balance  \
# 0    Aitcheson  Shane Andrew                       17.53              4.70
# 1             Antrobus  Dean                       11.20              7.84
# 2       Aston  Stephen James                       10.00             11.84
# 3  Baggstrom  Kimberley Dawn                        9.00              3.82
# 4         Baker  Anthony Ian                        0.00              2.23
#
#   Finish Date        Region
# 0         NaN  South Island
# 1         NaN  South Island
# 2         NaN  South Island
# 3         NaN  South Island
# 4         NaN  South Island
#
# [5 rows x 24 columns]

# %%
missing_info(salaried)
# Out:
#                              missing_count  missing_ratio
# Name                                     0       0.000000
# Alpha Code                               0       0.000000
# Start Date                               0       0.000000
# Department                               0       0.000000
# Employment  Status                       0       0.000000
# Salary/ Wage                             0       0.000000
# Hours Worked                             0       0.000000
# Birth Date                               1       0.001866
# Occupation                               0       0.000000
# Ethnicity                                0       0.000000
# Visa Type                                0       0.000000
# Visa Duration                            0       0.000000
# Visa Expiry                            529       0.986940
# EstimatedFixedTermExpiry               381       0.710821
# FixedTermAgreement                     381       0.710821
# Fixed Term Expiry                      512       0.955224
# Gender                                   0       0.000000
# Status                                   0       0.000000
# Name_Key                                 0       0.000000
# Employee Full Name                     381       0.710821
#  Sick/Special Leave Balance            381       0.710821
#  Holidays Balance                      381       0.710821
# Finish Date                            155       0.289179
# Region                                   0       0.000000

# %%
salaried.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 536 entries, 0 to 185
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name                         536 non-null    object
#  1   Alpha Code                   536 non-null    object
#  2   Start Date                   536 non-null    object
#  3   Department                   536 non-null    object
#  4   Employment  Status           536 non-null    object
#  5   Salary/ Wage                 536 non-null    object
#  6   Hours Worked                 536 non-null    float64
#  7   Birth Date                   535 non-null    object
#  8   Occupation                   536 non-null    object
#  9   Ethnicity                    536 non-null    object
#  10  Visa Type                    536 non-null    object
#  11  Visa Duration                536 non-null    object
#  12  Visa Expiry                  7 non-null      object
#  13  EstimatedFixedTermExpiry     155 non-null    object
#  14  FixedTermAgreement           155 non-null    object
#  15  Fixed Term Expiry            24 non-null     datetime64[ns]
#  16  Gender                       536 non-null    object
#  17  Status                       536 non-null    object
#  18  Name_Key                     536 non-null    object
#  19  Employee Full Name           155 non-null    object
#  20   Sick/Special Leave Balance  155 non-null    float64
#  21   Holidays Balance            155 non-null    float64
#  22  Finish Date                  381 non-null    object
#  23  Region                       536 non-null    object
# dtypes: datetime64[ns](1), float64(3), object(20)
# memory usage: 104.7+ KB

# %% [markdown]
# ### Combining salaried and waged data

# %%
mismatch=False
for s,w in zip(salaried.columns,waged.columns):
    if s != w:
        mismatch=True
if mismatch: 
    print("There is a mismatch of columns, please reorder appropriately")
    raise ValueError()
else:
    print("No Column Mismatch, can combine waged and salaried!")
# Out:
# No Column Mismatch, can combine waged and salaried!

# %%
employee_data = pd.concat([salaried,waged])

#drop name key and employee full name
employee_data.drop(columns=["Employee Full Name","Name_Key"],inplace=True)

#add a last updated column

employee_data["Data Last Updated At"] = dt.now()

get_info(employee_data)
# Out:
# ==================================================
# (1190, 23)
#                         Name Alpha Code           Start Date  \
# 0    Aitcheson, Shane Andrew   AITCHESO  2015-01-12 00:00:00
# 1             Antrobus, Dean   ANTRO001  2021-01-11 00:00:00
# 2       Aston, Stephen James   ASTON     2023-10-30 00:00:00
# 3  Baggstrom, Kimberley Dawn   BAGGSTRO  2023-09-07 00:00:00
# 4         Baker, Anthony Ian   BAKER001  2024-01-22 00:00:00
#
#                  Department Employment  Status Salary/ Wage  Hours Worked  \
# 0  25 - Projects Management          Permanent     Salary            45.0
# 1  23 - Projects Commercial          Permanent     Salary            45.0
# 2  25 - Projects Management          Permanent     Salary            45.0
# 3       13 - Administration          Permanent     Salary            40.0
# 4  30 - External Consultant          Permanent     Salary            40.0
#
#             Birth Date                           Occupation  \
# 0  1985-09-11 00:00:00  Project Manager
# 1  1969-01-29 00:00:00  Senior Quantity Surveyor
# 2  1980-07-16 00:00:00  Site Manager
# 3  1990-05-19 00:00:00  Regional Management Team Administra
# 4  1983-11-18 00:00:00  Job Pac Consultant
#
#                                            Ethnicity  ...  \
# 0                                                ...  ...
# 1                                                ...  ...
# 2  British                                       ...  ...
# 3  NZ Maori, European                            ...  ...
# 4  NZ European                                   ...  ...
#
#   EstimatedFixedTermExpiry FixedTermAgreement Fixed Term Expiry  \
# 0                    False              False               NaT
# 1                    False              False               NaT
# 2                    False              False               NaT
# 3                    False              False               NaT
# 4                    False               True        2024-05-10
#
#            Gender  Status  Sick/Special Leave Balance  Holidays Balance  \
# 0  Male            Active                       17.53              4.70
# 1  Male            Active                       11.20              7.84
# 2  Male            Active                       10.00             11.84
# 3  Female          Active                        9.00              3.82
# 4  Male            Active                        0.00              2.23
#
#   Finish Date        Region       Data Last Updated At
# 0         NaN  South Island 2024-06-04 08:46:11.245742
# 1         NaN  South Island 2024-06-04 08:46:11.245742
# 2         NaN  South Island 2024-06-04 08:46:11.245742
# 3         NaN  South Island 2024-06-04 08:46:11.245742
# 4         NaN  South Island 2024-06-04 08:46:11.245742
#
# [5 rows x 23 columns]
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 1190 entries, 0 to 107
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name                         1190 non-null   object
#  1   Alpha Code                   1190 non-null   object
#  2   Start Date                   1190 non-null   object
#  3   Department                   1190 non-null   object
#  4   Employment  Status           1190 non-null   object
#  5   Salary/ Wage                 1190 non-null   object
#  6   Hours Worked                 1190 non-null   float64
#  7   Birth Date                   1183 non-null   object
#  8   Occupation                   1190 non-null   object
#  9   Ethnicity                    1190 non-null   object
#  10  Visa Type                    1190 non-null   object
#  11  Visa Duration                1190 non-null   object
#  12  Visa Expiry                  58 non-null     object
#  13  EstimatedFixedTermExpiry     296 non-null    object
#  14  FixedTermAgreement           296 non-null    object
#  15  Fixed Term Expiry            32 non-null     datetime64[ns]
#  16  Gender                       1190 non-null   object
#  17  Status                       1190 non-null   object
#  18   Sick/Special Leave Balance  296 non-null    float64
#  19   Holidays Balance            296 non-null    float64
#  20  Finish Date                  893 non-null    object
#  21  Region                       1190 non-null   object
#  22  Data Last Updated At         1190 non-null   datetime64[us]
# dtypes: datetime64[ns](1), datetime64[us](1), float64(3), object(18)
# memory usage: 223.1+ KB
# None
#
# ==================================================

# %%
missing_info(employee_data)
#fixed term expiry still not parsing
#holiday and sick leave not joining
# Out:
#                              missing_count  missing_ratio
# Name                                     0       0.000000
# Alpha Code                               0       0.000000
# Start Date                               0       0.000000
# Department                               0       0.000000
# Employment  Status                       0       0.000000
# Salary/ Wage                             0       0.000000
# Hours Worked                             0       0.000000
# Birth Date                               7       0.005882
# Occupation                               0       0.000000
# Ethnicity                                0       0.000000
# Visa Type                                0       0.000000
# Visa Duration                            0       0.000000
# Visa Expiry                           1132       0.951261
# EstimatedFixedTermExpiry               894       0.751261
# FixedTermAgreement                     894       0.751261
# Fixed Term Expiry                     1158       0.973109
# Gender                                   0       0.000000
# Status                                   0       0.000000
#  Sick/Special Leave Balance            894       0.751261
#  Holidays Balance                      894       0.751261
# Finish Date                            297       0.249580
# Region                                   0       0.000000
# Data Last Updated At                     0       0.000000

# %% [markdown]
# ### Exporting tidied data to file for use in powerBI

# %%
#reset index on table
employee_data.reset_index(drop=True,inplace=True)

# %%
employee_data.to_csv('employee_data_tidy.csv')
print("Data Cleaned successfully!")
# Out:
# Data Cleaned successfully!

# %%
#change back to data analytics directory. Add a copy of data to make the active version 
os.chdir(r"C:\Users\alex.jefferies\Leighs Construction Limited\Data Analytics - Documents\General\Projects\HR\People Dashboard")
employee_data.to_csv('employee_data_tidy_active.csv')
print("Data Copied successfully!")
# Out:
# Data Copied successfully!

# %%
#render table as html
#table_to_html(employee_data)

# %%
#copy copy file to "History" subfolder
filename = f"employee_data_{dt.strftime(dt.today(),format="%m%Y")}.csv"
employee_data.to_csv(f"History/{filename}", index=False)
